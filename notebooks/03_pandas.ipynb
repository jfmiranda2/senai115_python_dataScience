# %% [markdown]
# # Definição

# %% [markdown]
# ![pandas.jpeg](data:image/jpeg;base64,...)
#
#
# Pandas é uma ferramenta de análise e manipulação de dados de código aberto rápida, poderosa, flexível e fácil de usar,
# construído sobre a linguagem de programação Python.
#
# Ela oferece estruturas de dados flexíveis e ferramentas para trabalhar com dados estruturados (tabelas, séries temporais, entre outros). Aqui estão alguns dos principais componentes e funcionalidades do Pandas:
#
# 1. **Estruturas de Dados:**
#
# 2. **Leitura e Escrita de Dados:**
#
# 3. **Indexação e Seleção de Dados:**
#
# 4. **Manipulação de Dados:**
#
# 5. **Tratamento de Dados Faltantes:**
#
# 6. **Operações Matemáticas e Estatísticas:**
#
# 7. **Combinação e Junção de Dados:**
#
# 8. **Análise de Séries Temporais:**

# %% [markdown]
# # Dicionário

# %%
alunos_senai = {
    "nome": "Lucas",
    "matricula": [1010, 1011, 1012],
    "turno": ["matutino", "noturno", "intregral"]
}
alunos_senai["nome"] = ["Edson", "Arantes", "Nascimento"]
alunos_senai['aprovado'] = [True, False, True]
print(alunos_senai["nome"])
print(alunos_senai)
print(type(alunos_senai))
# Out:
# ['Edson', 'Arantes', 'Nascimento']
# {'nome': ['Edson', 'Arantes', 'Nascimento'], 'matricula': [1010, 1011, 1012], 'turno': ['matutino', 'noturno', 'intregral'], 'aprovado': [True, False, True]}
# <class 'dict'>

# %% [markdown]
# # Instalação e importação pandas

# %%
import pandas as pd

# %%
#criar um dicionário com dados de alunos: Nome / Matricula / Turno

# %%
df_alunos_senai = pd.DataFrame(alunos_senai)
df_alunos_senai
# Out:
#          nome  matricula      turno  aprovado
# 0       Edson       1010   matutino      True
# 1     Arantes       1011    noturno     False
# 2  Nascimento       1012  intregral      True

# %% [markdown]
# # Importação e Exportação de Dados

# %%
#Exportação DataFrame para .csv (valores separados por virgulas)
df_alunos_senai.to_csv('alunos_senai.csv')

df_alunos_senai.to_excel('alunos_senai.xlsx')

# %%
df_casas = pd.read_csv('/content/sample_data/california_housing_test.csv')
df_casas
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# # Manipulação de dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/jfmiranda2/python_data_science/main/dataSets/Pokemon.csv"
df_pokemon = pd.read_csv(url)

#Resumo dos dados
df_pokemon.head(7) #Apresentar as primeiras linhas da tabela
df_pokemon.shape #Apresentar a quantidade de linhas e colunas da tabela
df_pokemon.describe() #Apresentas as estatísticas da tabela
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df_pokemon.columns = ['#', 'Nome', 'Tipo 1', 'Tipo 2', 'Total', 'HP', 'Ataque', 'Defesa',
       'Ataque Esp.', 'Defesa Esp.', 'Velocidade', 'Geração', 'Lendária']

df_pokemon.head(2)
# Out:
#    #       Nome Tipo 1  Tipo 2  Total  HP  Ataque  Defesa  Ataque Esp.  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49      49           65
# 1  2    Ivysaur  Grass  Poison    405  60      62      63           80
#
#    Defesa Esp.  Velocidade  Geração  Lendária
# 0           65          45        1     False
# 1           80          60        1     False

# %%
#Leitura Colunas
df_pokemon['Ataque'].head() #Filtro de apenas uma coluna
#df_pokemon_filtrado = df_pokemon[['Ataque Esp.','Ataque', 'Defesa', 'Total']].head()
df_pokemon_filtrado = df_pokemon[['Ataque Esp.','Ataque', 'Defesa', 'Total']][13:20]
display(df_pokemon_filtrado)
# Out:
#     Ataque Esp.  Ataque  Defesa  Total
# 13           20      30      35    195
# 14           25      20      55    205
# 15           90      45      50    395
# 16           20      35      30    195
# 17           25      25      50    205
# 18           45      90      40    395
# 19           15     150      40    495

# %%
#Leitura Linhas
#.loc
df_pokemon_filtrado = df_pokemon[['Ataque Esp.','Ataque', 'Defesa', 'Total']][13:20]
df_pokemon_filtrado = df_pokemon.loc[13:20 ,['Ataque Esp.','Ataque', 'Defesa', 'Total']]
df_pokemon_filtrado
# Out:
#     Ataque Esp.  Ataque  Defesa  Total
# 13           20      30      35    195
# 14           25      20      55    205
# 15           90      45      50    395
# 16           20      35      30    195
# 17           25      25      50    205
# 18           45      90      40    395
# 19           15     150      40    495
# 20           35      45      40    251

# %%
#.iloc

df_pokemon.iloc[0:5, -1] # Filtro linha 0 até a linha 5 apresentando apenas a última coluna
df_pokemon.iloc[:, 0] #Todas as linhas com a primeira coluna
df_pokemon.iloc[[0, 7, 8], 5:8]# Filtro linhas específicas com as colunas 5 até a 8
# Out:
#    HP  Ataque  Defesa
# 0  45      49      49
# 7  78     130     111
# 8  78     104      78

# %%
#Filtragem pelos dados

#AND = E = & - As duas condições devem ser verdadeiras para apresentar a linha
#df_pokemon.loc[(df_pokemon['Tipo 1'] == 'Grass') & (df_pokemon['Ataque'] > 100)]

#OR = OU = | = + - Uma das condições deve ser verdadeira para apresentar a linha
df_pokemon_filtrado = df_pokemon.loc[(df_pokemon['Tipo 1'] == 'Grass') | (df_pokemon['Tipo 1'] == 'Fire')]
df_pokemon_filtrado['Tipo 1'].value_counts()
# Out:
# Tipo 1
# Grass    70
# Fire     52
# Name: count, dtype: int64

# %%
#Ordem das colunas

df_pokemon.sort_values(['Ataque', 'Defesa'], ascending= [True, False])
# Out:
#        #                     Nome   Tipo 1    Tipo 2  Total   HP  Ataque  \
# 121  113                  Chansey   Normal       NaN    450  250       5
# 488  440                  Happiny   Normal       NaN    220  100       5
# 230  213                  Shuckle      Bug      Rock    505   20      10
# 139  129                 Magikarp    Water       NaN    200   20      10
# 261  242                  Blissey   Normal       NaN    540  255      10
# ..   ...                      ...      ...       ...    ...  ...     ...
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
#
#      Defesa  Ataque Esp.  Defesa Esp.  Velocidade  Geração  Lendária
# ...

# %% [markdown]
# # Manipulação de Dados Faltantes

# %%
#Identificação de Dados Faltantes
#isnull(), notnull().
#df_pokemon.head(10)
#df_pokemon.isnull() #retorna valor TRUE quando tiver um dado nulo
df_pokemon.notnull() #retorna valor FALSE quando tiver um dado nulo
# Out:
#         #  Nome  Tipo 1  Tipo 2  Total    HP  Ataque  Defesa  Ataque Esp.  \
# 0    True  True    True    True   True  True    True    True         True
# 1    True  True    True    True   True  True    True    True         True
# 2    True  True    True    True   True  True    True    True         True
# 3    True  True    True    True   True  True    True    True         True
# 4    True  True    True   False   True  True    True    True         True
# ..    ...   ...     ...     ...    ...   ...     ...     ...          ...
# 795  True  True    True    True   True  True    True    True         True
# 796  True  True    True    True   True  True    True    True         True
# 797  True  True    True    True   True  True    True    True         True
# 798  True  True    True    True   True  True    True    True         True
# 799  True  True    True    True   True  True    True    True         True
#
#      Defesa Esp.  Velocidade  Geração  Lendária
# ...

# %%
df_pokemon.loc[(df_pokemon['Tipo 2'].isnull() == True)]
# Out:
#        #        Nome  Tipo 1 Tipo 2  Total   HP  Ataque  Defesa  Ataque Esp.  \
# 4      4  Charmander    Fire    NaN    309   39      52      43           60
# 5      5  Charmeleon    Fire    NaN    405   58      64      58           80
# 9      7    Squirtle   Water    NaN    314   44      48      65           50
# 10     8   Wartortle   Water    NaN    405   59      63      80           65
# 11     9   Blastoise   Water    NaN    530   79      83     100           85
# ..   ...         ...     ...    ...    ...  ...     ...     ...          ...
# 775  705     Sliggoo  Dragon    NaN    452   68      75      53           83
# 776  706      Goodra  Dragon    NaN    600   90     100      70          110
# 788  712    Bergmite     Ice    NaN    304   55      69      85           32
# 789  713     Avalugg     Ice    NaN    514   95     117     184           44
# 792  716     Xerneas   Fairy    NaN    680  126     131      95          131
#
# ...

# %%
df_pokemon_nulo = df_pokemon
df_pokemon_nulo['status'] = None

# Exibir a quantidade de valores nulos por colun
#print(df_pokemon.isnull().sum())
print(df_pokemon_nulo.isnull().sum())
df_pokemon_nulo.head(10)
# Exibir a quantidade total de valores nulos no DataFrame
#df_pokemon.isnull().sum().sum()
# Out:
# #                0
# Nome             0
# Tipo 1           0
# Tipo 2         386
# Total            0
# HP               0
# Ataque           0
# Defesa           0
# Ataque Esp.      0
# Defesa Esp.      0
# Velocidade       0
# Geração          0
# Lendária         0
# status         800
# dtype: int64
#    #                       Nome Tipo 1  Tipo 2  Total  HP  Ataque  Defesa  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49      49
# 1  2                    Ivysaur  Grass  Poison    405  60      62      63
# 2  3                   Venusaur  Grass  Poison    525  80      82      83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100     123
# 4  4                 Charmander   Fire     NaN    309  39      52      43
# 5  5                 Charmeleon   Fire     NaN    405  58      64      58
# 6  6                  Charizard   Fire  Flying    534  78      84      78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130     111
# ...

# %%
df_pokemon['Tipo 2'].value_counts()
# Out:
# Tipo 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: count, dtype: int64

# %%
#Remoção de dados faltantes

df_pokemon_editado = df_pokemon.dropna() #Remove as linhas
print(df_pokemon.shape)
print(df_pokemon_editado.shape)
# Out:
# (800, 13)
# (414, 13)

# %%
df_pokemon_editado = df_pokemon.dropna(axis=1) #Remove as colunas
print(df_pokemon.shape) #tabela original
print(df_pokemon_editado.shape) #tabela editada sem a coluna com dados vazios
display(df_pokemon) #apresenta tabela original
display(df_pokemon_editado) #apresenta tabela editada
# Out:
# (800, 13)
# (800, 12)
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#Substituindo os valores vazios
df_pokemon_editado = df_pokemon.fillna('Corinthians') #Substituir valores vazios com 0
#df_pokemon_editado = df_pokemon.fillna(False) #Substituir valores vazios com False
print(df_pokemon.isnull().sum())
print(df_pokemon_editado.isnull().sum())

print(df_pokemon_editado['Tipo 2'].value_counts())
# Out:
# #                0
# Nome             0
# Tipo 1           0
# Tipo 2         386
# Total            0
# HP               0
# Ataque           0
# Defesa           0
# Ataque Esp.      0
# Defesa Esp.      0
# Velocidade       0
# Geração          0
# Lendária         0
# dtype: int64
# #              0
# Nome           0
# Tipo 1         0
# Tipo 2         0
# Total          0
# HP             0
# Ataque         0
# Defesa         0
# Ataque Esp.    0
# Defesa Esp.    0
# Velocidade     0
# Geração        0
# Lendária       0
# dtype: int64
# Tipo 2
# Corinthians    386
# Flying          97
# Ground          35
# Poison          34
# Psychic         33
# Fighting        26
# Grass           25
# Fairy           23
# Steel           22
# Dark            20
# Dragon          18
# Ice             14
# Rock            14
# Water           14
# Ghost           14
# Fire            12
# Electric         6
# Normal           4
# Bug              3
# Name: count, dtype: int64

# %%
#Substituindo os valores vazios
#df_pokemon_editado = df_pokemon.fillna(0) #Substituir valores vazios com 0
df_pokemon_editado = df_pokemon.fillna(method="ffill") #Substituir valores vazios o valor da linha anterior
print(df_pokemon.isnull().sum())
print(df_pokemon_editado.isnull().sum())
print(df_pokemon_editado['Tipo 2'].value_counts())
df_pokemon_editado.head(10)
# Out:
# #                0
# Nome             0
# Tipo 1           0
# Tipo 2         386
# Total            0
# HP               0
# Ataque           0
# Defesa           0
# Ataque Esp.      0
# Defesa Esp.      0
# Velocidade       0
# Geração          0
# Lendária         0
# dtype: int64
# #              0
# Nome           0
# Tipo 1         0
# Tipo 2         0
# Total          0
# HP             0
# Ataque         0
# Defesa         0
# Ataque Esp.    0
# Defesa Esp.    0
# Velocidade     0
# Geração        0
# Lendária       0
# dtype: int64
# Tipo 2
# Flying      177
# Fighting     78
# Psychic      77
# Ground       72
# Poison       52
# Fairy        42
# Steel        41
# Dragon       36
# Grass        34
# Rock         32
# Dark         29
# Ice          27
# Fire         24
# Ghost        24
# Water        22
# Bug          12
# Electric     11
# Normal       10
# Name: count, dtype: int64
# ...

# %%
df_pokemon.head(50)
# Out:
#      #                       Nome    Tipo 1  Tipo 2  Total   HP  Ataque  \
# 0    1                  Bulbasaur     Grass  Poison    318   45      49
# 1    2                    Ivysaur     Grass  Poison    405   60      62
# 2    3                   Venusaur     Grass  Poison    525   80      82
# 3    3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4    4                 Charmander      Fire     NaN    309   39      52
# 5    5                 Charmeleon      Fire     NaN    405   58      64
# 6    6                  Charizard      Fire  Flying    534   78      84
# 7    6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8    6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9    7                   Squirtle     Water     NaN    314   44      48
# 10   8                  Wartortle     Water     NaN    405   59      63
# 11   9                  Blastoise     Water     NaN    530   79      83
# ...

# %% [markdown]
# # Operações e Transformações

# %%
#Operações Matemáticas e Estatísticas Básicas
#mean(), sum(), std(), etc.
print(df_pokemon['Ataque'].max())
print(df_pokemon['Ataque'].min())
print(df_pokemon['Ataque'].mean())
print(df_pokemon['Ataque'].sum())
print(df_pokemon['Ataque'].std()) #desvio padrão https://www.todamateria.com.br/desvio-padrao/
# Out:
# 190
# 5
# 79.00125
# 63201
# 32.45736586949845

# %%
#Agrupamento de dados
#df_pokemon.groupby(['Tipo 1']).sum()
#df_pokemon[['Tipo 1','Total', 'HP', 'Ataque', 'Defesa',
#       'Ataque Esp.', 'Defesa Esp.', 'Velocidade']].groupby(['Tipo 1']).sum()

df_pokemon.groupby('Tipo 1')[['Total','HP']].mean()
# Out:
#                Total         HP
# Tipo 1
# Bug       378.927536  56.884058
# Dark      445.741935  66.806452
# Dragon    550.531250  83.312500
# Electric  443.409091  59.795455
# Fairy     413.176471  74.117647
# Fighting  416.444444  69.851852
# Fire      458.076923  69.903846
# Flying    485.000000  70.750000
# Ghost     439.562500  64.437500
# Grass     421.142857  67.271429
# Ground    437.500000  73.781250
# Ice       433.458333  72.000000
# Normal    401.683673  77.275510
# Poison    399.142857  67.250000
# Psychic   475.947368  70.631579
# Rock      453.750000  65.363636
# Steel     487.703704  65.222222
# Water     430.455357  72.062500
